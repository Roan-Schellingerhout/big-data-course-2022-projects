# %%
import pandas as pd
import numpy as np

from itertools import groupby
from sklearn.preprocessing import MultiLabelBinarizer

import json
import glob

# %%
def openfile(data):
    if data == "writers":
        with open("writing.json") as f:
            writers = f.read()
        
        return json.loads(writers)
    elif data == "directors":
        with open("directing.json") as f:
            directors = f.read()
        
        return json.loads(directors)    
    else:
        return NotImplemented

# %%
def json_to_one_hot(kind = "writers"):

    if kind in ["writers", "directors"]:
        json_file = openfile(kind)
    else:
        return NotImplemented
  
    if kind == "writers":
         # Group writers/directors by movie
        groups = groupby([(i["movie"], i["writer"]) for i in json_file], key = lambda x : x[0])

        # Turn groupby object into a json-like dict
        grouped = {writer: [i[1] for i in movies] for writer, movies in groups}

        # Convert to Series
        df = pd.DataFrame.from_records(list(grouped.items())).set_index(0).squeeze()
    else:
        df = pd.DataFrame(json_file).groupby("movie")["director"].apply(lambda x: x.values)
    
    # Create one-hot encoded DataFrame
    mlb = MultiLabelBinarizer()
    res = pd.DataFrame(mlb.fit_transform(df),
                       columns=mlb.classes_,
                       index=df.index)
    
    return res.drop("\\N", axis = 1)

# %%
all_files = glob.glob("train*.csv")

print(f"Found files: {', '.join(all_files)}")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True).drop("Unnamed: 0", axis = 1)
# Out:
# Found files: train-6.csv, train-7.csv, train-5.csv, train-4.csv, train-1.csv, train-3.csv, train-2.csv, train-8.csv

# %%
df = df.replace("\\N", np.nan)

# %%
df.head()
# Out:
#       tconst     primaryTitle    originalTitle startYear endYear  \
# 0  tt0013257            Häxan            Häxan      1922     NaN
# 1  tt0013556       Robin Hood              NaN      1922     NaN
# 2  tt0014341  Our Hospitality  Our Hospitality      1923     NaN
# 3  tt0014538       Three Ages              NaN      1923     NaN
# 4  tt0017925      The General              NaN      1926     NaN
#
#   runtimeMinutes  numVotes  label
# 0             91   13679.0   True
# 1            143    2178.0   True
# 2             65   10911.0   True
# 3             63    4312.0   True
# 4             67   87784.0   True

# %%
df["label"].value_counts()
# Out:
# True     3990
# False    3969
# Name: label, dtype: int64

# %%
df.isna().mean()
# Out:
# tconst            0.000000
# primaryTitle      0.000000
# originalTitle     0.501068
# startYear         0.098756
# endYear           0.901244
# runtimeMinutes    0.001633
# numVotes          0.099259
# label             0.000000
# dtype: float64

# %%
oscars = pd.read_csv("oscars.csv")

# %%
oscars.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
# Cleaning titles and merging with oscar noms
df["primaryTitle"] = df["primaryTitle"].str.lower()\
                                       .str.normalize('NFKD')\
                                       .str.encode('ascii', errors='ignore')\
                                       .str.decode('utf-8')\
                                       .str.replace(" ", "_", regex=True)\
                                       .str.replace("\W", "", regex=True)

oscars["film"] = oscars["film"].str.lower()\
                               .str.normalize('NFKD')\
                               .str.encode('ascii', errors='ignore')\
                               .str.decode('utf-8')\
                               .str.replace(" ", "_", regex=True)\
                               .str.replace("\W", "", regex=True)

# %%
# Counting oscar nominations and wins per movie
oscar_noms = pd.merge(df, oscars, left_on = "primaryTitle", right_on = "film").groupby("tconst")["winner"].count()
oscar_wins = pd.merge(df, oscars, left_on = "primaryTitle", right_on = "film").groupby("tconst")["winner"].sum()

# %%
df = df.rename({"tconst" : "id"}, axis = 1).set_index("id")

# %%
df["oscar_noms"] = oscar_noms
df["oscar_wins"] = oscar_wins

# %%
# Find writers and directors per movie and combine the two
written_and_directed = (json_to_one_hot("writers") + json_to_one_hot("directors")).fillna(0).astype(int).loc[df.index]

# %%
# Add writer/director data to df (the transposes are done to speed things up)
df = pd.concat([df.T, written_and_directed.T]).T

# %%
df.head(20)
# Out:
#                           primaryTitle               originalTitle startYear  \
# id
# tt0013257                        haxan                       Häxan      1922
# tt0013556                   robin_hood                         NaN      1922
# tt0014341              our_hospitality             Our Hospitality      1923
# tt0014538                   three_ages                         NaN      1923
# tt0017925                  the_general                         NaN      1926
# tt0018192                     napoleon  Napoléon vu par Abel Gance      1927
# tt0018526                   underworld                         NaN      1927
# tt0018806                    the_crowd                   The Crowd       NaN
# tt0019788                     coquette                    Coquette       NaN
# tt0023871             a_song_of_lisbon          A Canção de Lisboa      1933
# tt0023969                    duck_soup                   Duck Soup      1933
# tt0025410           little_miss_marker          Little Miss Marker      1934
# tt0026529                 the_informer                The Informer       NaN
# tt0027914              love_on_the_run                         NaN      1936
# tt0028212                     sabotage                    Sabotage      1936
# tt0028249                    show_boat                         NaN      1936
# tt0028944               the_good_earth              The Good Earth       NaN
# tt0029146       the_life_of_emile_zola      The Life of Emile Zola      1937
# tt0029314  humanity_and_paper_balloons                         NaN      1937
# tt0029995                  the_citadel                         NaN      1938
#
#           endYear runtimeMinutes numVotes  label oscar_noms oscar_wins  \
# id
# tt0013257     NaN             91  13679.0   True        NaN        NaN
# tt0013556     NaN            143   2178.0   True        1.0        0.0
# tt0014341     NaN             65  10911.0   True        NaN        NaN
# tt0014538     NaN             63   4312.0   True        NaN        NaN
# tt0017925     NaN             67  87784.0   True        NaN        NaN
# tt0018192     NaN            330   7622.0   True        NaN        NaN
# tt0018526     NaN             80   2912.0   True        1.0        1.0
# tt0018806    1928             98   8197.0   True        2.0        0.0
# tt0019788    1929             76   2127.0  False        1.0        1.0
# tt7134096                the_rhythm_section      The Rhythm Section      2020
# tt8017136  tony_my_mentor_the_serial_killer                    Tony       NaN
# tt8671462                        invoking_5              Invoking 5      2018
# tt8694228                           mikhael                     NaN      2019
# tt9110170                        wrong_turn              Wrong Turn      2021
#
#           endYear runtimeMinutes numVotes  label oscar_noms oscar_wins  \
# id
# tt0029146     NaN            116      NaN   True       10.0        3.0
# tt0034521     NaN             64      NaN  False        NaN        NaN
# tt0039651     NaN             72      NaN   True        NaN        NaN
# tt0042436     NaN            105      NaN   True        NaN        NaN
# tt0046446     NaN             90      NaN  False        1.0        0.0
# ...           ...            ...      ...    ...        ...        ...
# tt7134096     NaN            109      NaN  False        NaN        NaN
# tt8017136    2018            124      NaN   True        NaN        NaN
# tt8671462     NaN             90      NaN  False        NaN        NaN
# tt8694228     NaN            150      NaN  False        NaN        NaN
# tt9110170     NaN            109      NaN  False        NaN        NaN
#
#           nm0000005  ... nm9925241 nm9933959 nm9942830 nm9946633 nm9955258  \
# id                   ...
# tt0029146         0  ...         0         0         0         0         0
# tt0034521         0  ...         0         0         0         0         0
# tt0039651         0  ...         0         0         0         0         0
# tt0042436         0  ...         0         0         0         0         0
# tt0046446         0  ...         0         0         0         0         0
# ...             ...  ...       ...       ...       ...       ...       ...
# tt7134096         0  ...         0         0         0         0         0
# tt8017136         0  ...         0         0         0         0         0
# tt8671462         0  ...         0         0         0         0         0
# tt8694228         0  ...         0         0         0         0         0
# tt9110170         0  ...         0         0         0         0         0
#
#           nm9958352 nm9958353 nm9980769 nm9985316 nm9985837
# id
# tt0029146         0         0         0         0         0
# tt0034521         0         0         0         0         0
# tt0039651         0         0         0         0         0
# tt0042436         0         0         0         0         0
# tt0046446         0         0         0         0         0
# ...             ...       ...       ...       ...       ...
# tt7134096         0         0         0         0         0
# tt8017136         0         0         0         0         0
# tt8671462         0         0         0         0         0
# tt8694228         0         0         0         0         0
# tt9110170         0         0         0         0         0
#
# [790 rows x 17917 columns]

# %%
type(df.loc['tt0029146']['numVotes'])
# Out:
# float

# %%
df[['numVotes', 'label']]
# Out:
#           numVotes  label
# id
# tt0013257  13679.0   True
# tt0013556   2178.0   True
# tt0014341  10911.0   True
# tt0014538   4312.0   True
# tt0017925  87784.0   True
# ...            ...    ...
# tt9625664  12951.0  False
# tt9741310   2464.0  False
# tt9742392   1719.0  False
# tt9850386   4144.0   True
# tt9911196   3242.0   True
#
# [7959 rows x 2 columns]

# %%
df['numVotes'] = df['numVotes'].fillna(0)
df["label"] = df["label"].astype(int)

# %%
abs(df["label"].corr(df["numVotes"]))
# Out:
# 0.16106479047663133

# %%
df.corr()
# Out:
#           numVotes     label
# numVotes  1.000000  0.161065
# label     0.161065  1.000000

# %%
display(df.sort_values(by='numVotes', ascending=False).head(100))
df.sort_values(by='numVotes', ascending=False).head(1000).corr()
# Out:
#                                 primaryTitle  \
# id
# tt0111161           the_shawshank_redemption
# tt0468569                    the_dark_knight
# tt0137523                         fight_club
# tt0109830                       forrest_gump
# tt0133093                         the_matrix
# ...                                      ...
# tt0441773                      kung_fu_panda
# tt1454029                           the_help
# tt1535109                   captain_phillips
# tt1515091  sherlock_holmes_a_game_of_shadows
# tt0887912                    the_hurt_locker
#
#                                 originalTitle startYear endYear  \
# id
# tt0111161            The Shawshank Redemption      1994     NaN
# tt0468569                     The Dark Knight       NaN    2008
# tt0137523                          Fight Club      1999     NaN
# tt0109830                        Forrest Gump      1994     NaN
# tt0133093                          The Matrix      1999     NaN
# ...                                       ...       ...     ...
# tt0441773                       Kung Fu Panda      2008     NaN
# tt1454029                                 NaN      2011     NaN
# tt1535109                    Captain Phillips      2013     NaN
# tt1515091  Sherlock Holmes: A Game of Shadows      2011     NaN
# tt0887912                                 NaN      2008     NaN
#
#           runtimeMinutes   numVotes  label oscar_noms oscar_wins nm0000005  \
# id
# tt0111161            142  2503641.0      1        7.0        0.0         0
# tt0468569            152  2453191.0      1        8.0        2.0         0
# tt0137523            139  1969585.0      1        1.0        0.0         0
# tt0109830            142  1932502.0      1       13.0        6.0         0
# tt0133093            136  1787064.0      1        4.0        4.0         0
# ...                  ...        ...    ...        ...        ...       ...
# tt0441773             92   443161.0      1        1.0        0.0         0
# tt1454029            146   442091.0      1        4.0        1.0         0
# tt1535109            134   441709.0      1        6.0        0.0         0
# tt1515091            129   437947.0      1        NaN        NaN         0
# tt0887912            131   437665.0      1        9.0        6.0         0
#
#            ... nm9925241 nm9933959 nm9942830 nm9946633 nm9955258 nm9958352  \
# id         ...
# tt0111161  ...         0         0         0         0         0         0
# tt0468569  ...         0         0         0         0         0         0
# tt0137523  ...         0         0         0         0         0         0
# tt0109830  ...         0         0         0         0         0         0
# tt0133093  ...         0         0         0         0         0         0
# ...        ...       ...       ...       ...       ...       ...       ...
# tt0441773  ...         0         0         0         0         0         0
# tt1454029  ...         0         0         0         0         0         0
# tt1535109  ...         0         0         0         0         0         0
# tt1515091  ...         0         0         0         0         0         0
# tt0887912  ...         0         0         0         0         0         0
#
#           nm9958353 nm9980769 nm9985316 nm9985837
# id
# tt0111161         0         0         0         0
# tt0468569         0         0         0         0
# tt0137523         0         0         0         0
# tt0109830         0         0         0         0
# tt0133093         0         0         0         0
# ...             ...       ...       ...       ...
# tt0441773         0         0         0         0
# tt1454029         0         0         0         0
# tt1535109         0         0         0         0
# tt1515091         0         0         0         0
# tt0887912         0         0         0         0
#
# [100 rows x 17917 columns]
#           numVotes     label
# numVotes  1.000000  0.255227
# label     0.255227  1.000000
