# %%
import pandas as pd
import numpy as np

from itertools import groupby
from sklearn.preprocessing import MultiLabelBinarizer

import json
import glob
import ast

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
def openfile(data):
    if data == "writers":
        with open("writing.json") as f:
            writers = f.read()
        
        return json.loads(writers)
    elif data == "directors":
        with open("directing.json") as f:
            directors = f.read()
        
        return json.loads(directors)    
    else:
        return NotImplemented

# %%
def json_to_one_hot(kind = "writers"):

    if kind in ["writers", "directors"]:
        json_file = openfile(kind)
    else:
        return NotImplemented
  
    if kind == "writers":
         # Group writers/directors by movie
        groups = groupby([(i["movie"], i["writer"]) for i in json_file], key = lambda x : x[0])

        # Turn groupby object into a json-like dict
        grouped = {writer: [i[1] for i in movies] for writer, movies in groups}

        # Convert to Series
        df = pd.DataFrame.from_records(list(grouped.items())).set_index(0).squeeze()
    else:
        df = pd.DataFrame(json_file).groupby("movie")["director"].apply(lambda x: x.values)
    
    # Create one-hot encoded DataFrame
    mlb = MultiLabelBinarizer()
    res = pd.DataFrame(mlb.fit_transform(df),
                       columns=mlb.classes_,
                       index=df.index)
    
    return res.drop("\\N", axis = 1)

# %%
all_files = glob.glob("train*.csv")

print(f"Found files: {', '.join(all_files)}")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True).drop("Unnamed: 0", axis = 1)
# Out:
# Found files: train-1.csv, train-2.csv, train-3.csv, train-4.csv, train-5.csv, train-6.csv, train-7.csv, train-8.csv

# %%
df = df.replace("\\N", np.nan)

# %%
df.head()
# Out:
#       tconst              primaryTitle             originalTitle startYear  \
# 0  tt0010600                  The Doll                 Die Puppe      1919
# 1  tt0011841             Way Down East             Way Down East      1920
# 2  tt0012494                   Déstiny              Der müde Tod      1921
# 3  tt0015163             The Navigator             The Navigator      1924
# 4  tt0016220  The Phantom of the Opera  The Phantom of the Opera      1925
#
#   endYear runtimeMinutes  numVotes  label
# 0     NaN             66    1898.0   True
# 1     NaN            145    5376.0   True
# 2     NaN             97    5842.0   True
# 3     NaN             59    9652.0   True
# 4     NaN             93   17887.0   True

# %%
df["label"].value_counts()
# Out:
# True     3990
# False    3969
# Name: label, dtype: int64

# %%
df.isna().mean()
# Out:
# tconst            0.000000
# primaryTitle      0.000000
# originalTitle     0.501068
# startYear         0.098756
# endYear           0.901244
# runtimeMinutes    0.001633
# numVotes          0.099259
# label             0.000000
# dtype: float64

# %%
oscars = pd.read_csv("additional_data/oscars.csv")

# %%
oscars.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
# Cleaning titles and merging with oscar noms
df["primaryTitle"] = df["primaryTitle"].str.lower()\
                                       .str.normalize('NFKD')\
                                       .str.encode('ascii', errors='ignore')\
                                       .str.decode('utf-8')\
                                       .str.replace(" ", "_", regex=True)\
                                       .str.replace("\W", "", regex=True)

oscars["film"] = oscars["film"].str.lower()\
                               .str.normalize('NFKD')\
                               .str.encode('ascii', errors='ignore')\
                               .str.decode('utf-8')\
                               .str.replace(" ", "_", regex=True)\
                               .str.replace("\W", "", regex=True)

# %%
# Counting oscar nominations and wins per movie
oscar_noms = pd.merge(df, oscars, left_on = "primaryTitle", right_on = "film").groupby("tconst")["winner"].count()
oscar_wins = pd.merge(df, oscars, left_on = "primaryTitle", right_on = "film").groupby("tconst")["winner"].sum()

# %%
df = df.rename({"tconst" : "id"}, axis = 1).set_index("id")

# %%
df["oscar_noms"] = oscar_noms
df["oscar_wins"] = oscar_wins

# %%
# Find writers and directors per movie and combine the two
written_and_directed = (json_to_one_hot("writers") + json_to_one_hot("directors")).fillna(0).astype(int).loc[df.index]

# %%
# Add writer/director data to df (the transposes are done to speed things up)
df = pd.concat([df.T, written_and_directed.T]).T

# %%
df.head()
# Out:
#                        primaryTitle             originalTitle startYear  \
# id
# tt0010600                  the_doll                 Die Puppe      1919
# tt0011841             way_down_east             Way Down East      1920
# tt0012494                   destiny              Der müde Tod      1921
# tt0015163             the_navigator             The Navigator      1924
# tt0016220  the_phantom_of_the_opera  The Phantom of the Opera      1925
#
#           endYear runtimeMinutes numVotes label oscar_noms oscar_wins  \
# id
# tt0010600     NaN             66   1898.0  True        NaN        NaN
# tt0011841     NaN            145   5376.0  True        NaN        NaN
# tt0012494     NaN             97   5842.0  True        NaN        NaN
# tt0015163     NaN             59   9652.0  True        NaN        NaN
# tt0016220     NaN             93  17887.0  True        3.0        0.0
#
#           nm0000005  ... nm9925241 nm9933959 nm9942830 nm9946633 nm9955258  \
# id                   ...
# tt0010600         0  ...         0         0         0         0         0
# tt0011841         0  ...         0         0         0         0         0
# tt0012494         0  ...         0         0         0         0         0
# tt0015163         0  ...         0         0         0         0         0
# tt0016220         0  ...         0         0         0         0         0
#
#           nm9958352 nm9958353 nm9980769 nm9985316 nm9985837
# id
# tt0010600         0         0         0         0         0
# tt0011841         0         0         0         0         0
# tt0012494         0         0         0         0         0
# tt0015163         0         0         0         0         0
# tt0016220         0         0         0         0         0
#
# [5 rows x 17917 columns]

# %% [markdown]
# ## Add TMDB data

# %%
df_2 = pd.read_csv("additional_data/TMDB.csv")

# %%
df_2 = df_2[["budget", "genres", "imdb_id", 
             "original_language", "overview", 
             "popularity", "production_companies", 
             "tagline", "Keywords", "revenue"]]

# %%
def dict_to_list(dictionary):
    try:
        d = ast.literal_eval(dictionary)
    except ValueError:
        return []
    
    return [i["name"] for i in d]

# %%
df_2["genres"] = df_2["genres"].apply(lambda x: dict_to_list(x))

# %%
df_2["Keywords"] = df_2["Keywords"].apply(lambda x: dict_to_list(x))

# %%
df_2["production_companies"] = df_2["production_companies"].apply(lambda x: dict_to_list(x))

# %%
df_full = pd.merge(df.reset_index(), df_2, how = "left", left_on = "id", right_on = "imdb_id").set_index("id")

# %%
del df

# %%
def embed_overviews(df_full, vector_size, epochs):
    df = df_full.copy()
    
    df["overview"] = df["overview"].str.lower().str.split()
    
    texts = df[~df["overview"].isna()]["overview"]
        
    documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(texts)]
    model = Doc2Vec(documents, vector_size = vector_size, epochs = epochs, min_count = 1)
        
    embeddings = df["overview"].apply(lambda x: 
                                      model.infer_vector(x)
                                      if type(x) == list
                                      else [np.nan] * vector_size)
                 
    return embeddings
    
vector_size = 10
epochs = 10
embeddings = pd.DataFrame(embed_overviews(df_full, vector_size, epochs).to_list(), 
                          columns = [f"embedding_{i}" for i in range(vector_size)]).set_index(df_full.index)

# %%
df_full = pd.merge(df_full, embeddings, left_index=True, right_index=True)

# %%
df_full.head(20)
# Out:
#                                   primaryTitle               originalTitle  \
# id
# tt0010600                             the_doll                   Die Puppe
# tt0011841                        way_down_east               Way Down East
# tt0012494                              destiny                Der müde Tod
# tt0015163                        the_navigator               The Navigator
# tt0016220             the_phantom_of_the_opera    The Phantom of the Opera
# tt0016630                      battling_butler             Battling Butler
# tt0021015                 juno_and_the_paycock                         NaN
# tt0023973               the_eagle_and_the_hawk                         NaN
# tt0023986                   employees_entrance                         NaN
# tt0024184                    the_invisible_man           The Invisible Man
# tt0024216                            king_kong                   King Kong
# tt0025028                                dames                         NaN
# tt0027478          the_crime_of_monsieur_lange  Le crime de Monsieur Lange
# tt0028333                           swing_time                         NaN
# tt0030341                    the_lady_vanishes           The Lady Vanishes
# tt0031143               the_cat_and_the_canary                         NaN
# tt0031385                     goodbye_mr_chips                         NaN
# tt0031647                             midnight                         NaN
# tt0031762               only_angels_have_wings                         NaN
# tt0032156  the_story_of_the_last_chrysanthemum          Zangiku monogatari
#
#           startYear endYear runtimeMinutes numVotes  label oscar_noms  \
# id
# tt0010600      1919     NaN             66   1898.0   True        NaN
# tt0011841      1920     NaN            145   5376.0   True        NaN
# tt0012494      1921     NaN             97   5842.0   True        NaN
# tt0015163      1924     NaN             59   9652.0   True        NaN
# tt0016220      1925     NaN             93  17887.0   True        3.0
# tt0016630      1926     NaN             77   3285.0   True        NaN
# tt0021015      1929     NaN             85   2275.0  False        NaN
# tt0023973      1933     NaN             73      NaN   True        NaN
# tt0023986      1933     NaN             75      NaN   True        NaN
# tt0024184      1933     NaN             71  33562.0   True        NaN
# tt0024216      1933     NaN            100  83177.0   True        7.0
# tt0025028      1934     NaN             91   2038.0   True        NaN
# tt0027478      1936     NaN             80      NaN   True        NaN
# tt0028333      1936     NaN            103      NaN   True        2.0
# tt0030341      1938     NaN             96  50707.0   True        NaN
# tt0031143      1939     NaN             72   2967.0   True        NaN
# tt0031385      1939     NaN            114  10311.0   True        9.0
# tt0031647      1939     NaN             94   4904.0   True        NaN
# tt0031762      1939     NaN            121  13595.0   True        2.0
# tt0032156      1939     NaN            143   3600.0   True        NaN
#
#           oscar_wins nm0000005  ... embedding_0 embedding_1 embedding_2  \
# id                              ...
# tt0010600        NaN         0  ...         NaN         NaN         NaN
# tt0011841        NaN         0  ...         NaN         NaN         NaN
# tt0012494        NaN         0  ...         NaN         NaN         NaN
# tt0015163        NaN         0  ...         NaN         NaN         NaN
# tt0016220        0.0         0  ...         NaN         NaN         NaN
# tt0016630        NaN         0  ...         NaN         NaN         NaN
# tt0021015        NaN         0  ...         NaN         NaN         NaN
# tt0023973        NaN         0  ...         NaN         NaN         NaN
# tt0023986        NaN         0  ...         NaN         NaN         NaN
# tt0024184        NaN         0  ...         NaN         NaN         NaN
# tt0024216        4.0         0  ...    0.027997    0.081269    0.012723
# tt0025028        NaN         0  ...         NaN         NaN         NaN
# tt0027478        NaN         0  ...         NaN         NaN         NaN
# tt0028333        1.0         0  ...   -0.009605    0.114383    0.112252
# tt0030341        NaN         0  ...         NaN         NaN         NaN
# tt0031143        NaN         0  ...         NaN         NaN         NaN
# tt0031385        1.0         0  ...         NaN         NaN         NaN
# tt0031647        NaN         0  ...         NaN         NaN         NaN
# tt0031762        0.0         0  ...         NaN         NaN         NaN
# tt0032156        NaN         0  ...         NaN         NaN         NaN
#
#           embedding_3 embedding_4 embedding_5 embedding_6 embedding_7  \
# id
# tt0010600         NaN         NaN         NaN         NaN         NaN
# tt0011841         NaN         NaN         NaN         NaN         NaN
# tt0012494         NaN         NaN         NaN         NaN         NaN
# tt0015163         NaN         NaN         NaN         NaN         NaN
# tt0016220         NaN         NaN         NaN         NaN         NaN
# tt0016630         NaN         NaN         NaN         NaN         NaN
# tt0021015         NaN         NaN         NaN         NaN         NaN
# tt0023973         NaN         NaN         NaN         NaN         NaN
# tt0023986         NaN         NaN         NaN         NaN         NaN
# tt0024184         NaN         NaN         NaN         NaN         NaN
# tt0024216   -0.028694    0.020671    0.047382    0.372767    0.193788
# tt0025028         NaN         NaN         NaN         NaN         NaN
# tt0027478         NaN         NaN         NaN         NaN         NaN
# tt0028333   -0.016658    0.064195   -0.068296    0.458318    0.195049
# tt0030341         NaN         NaN         NaN         NaN         NaN
# tt0031143         NaN         NaN         NaN         NaN         NaN
# tt0031385         NaN         NaN         NaN         NaN         NaN
# tt0031647         NaN         NaN         NaN         NaN         NaN
# tt0031762         NaN         NaN         NaN         NaN         NaN
# tt0032156         NaN         NaN         NaN         NaN         NaN
#
#           embedding_8 embedding_9
# id
# tt0010600         NaN         NaN
# tt0011841         NaN         NaN
# tt0012494         NaN         NaN
# tt0015163         NaN         NaN
# tt0016220         NaN         NaN
# tt0016630         NaN         NaN
# tt0021015         NaN         NaN
# tt0023973         NaN         NaN
# tt0023986         NaN         NaN
# tt0024184         NaN         NaN
# tt0024216   -0.340761   -0.080535
# tt0025028         NaN         NaN
# tt0027478         NaN         NaN
# tt0028333   -0.421537   -0.110436
# tt0030341         NaN         NaN
# tt0031143         NaN         NaN
# tt0031385         NaN         NaN
# tt0031647         NaN         NaN
# tt0031762         NaN         NaN
# tt0032156         NaN         NaN
#
# [20 rows x 17937 columns]

# %% [markdown]
# # Inspection of numVotes

# %%
df[df['numVotes'].isna()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8628/295171869.py in <module>
# ----> 1 df[df['numVotes'].isna()]
#
# NameError: name 'df' is not defined

# %%
type(df.loc['tt0029146']['numVotes'])

# %%
df[['numVotes', 'label']]

# %%
df['numVotes'] = df['numVotes'].fillna(0)
df["label"] = df["label"].astype(int)

# %%
abs(df["label"].corr(df["numVotes"]))

# %%
df.corr()

# %%
display(df.sort_values(by='numVotes', ascending=False).head(100))
df.sort_values(by='numVotes', ascending=False).head(1000).corr()
